# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Datasets/main_data.csv')

# %%
df
# Out:
#          BOX_ID   QUALITY                  DELIVERY_OPTION  MILK  MEAT  \
# 0             1   Premium              Home Delivery - CoD   0.0   2.7
# 1             2   Premium              Home Delivery - CoD   0.0   2.3
# 2             2   Premium              Home Delivery - CoD   0.0   2.3
# 3             2   Premium              Home Delivery - CoD   0.0   2.3
# 4             2   Premium              Home Delivery - CoD   0.0   2.3
# ...         ...       ...                              ...   ...   ...
# 1274082     288  Standard  Home Delivery - Digital Payment   0.0   3.6
# 1274083     288  Standard  Home Delivery - Digital Payment   0.0   3.6
# 1274084     288  Standard  Home Delivery - Digital Payment   0.0   3.6
# 1274085     290  Standard  Home Delivery - Digital Payment  12.0   1.8
# 1274086     290  Standard  Home Delivery - Digital Payment  12.0   1.8
#
#          UNIT_PRICE    MAGIC_KEY  BOX_COUNT
# 0              9.96  2C88D36D1FC          1
# 1             11.96  2BC4127366C          1
# 2             11.96  2BC4394CE95          1
# 3             11.96  2BC4D37C804          1
# 4             11.96  2BC4EA26F92          1
# ...             ...          ...        ...
# 1274082       15.96  293C58DD9DC          1
# 1274083       15.96  29E6A06C99B          1
# 1274084       15.96  2A0CABFA0DF          1
# 1274085       19.98  28F675D813E          1
# 1274086       19.98  28FF7857D43          1
#
# [1274087 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1274087 entries, 0 to 1274086
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   BOX_ID           1274087 non-null  int64
#  1   QUALITY          1274087 non-null  object
#  2   DELIVERY_OPTION  1274087 non-null  object
#  3   MILK             1274087 non-null  float64
#  4   MEAT             1274087 non-null  float64
#  5   UNIT_PRICE       1274087 non-null  float64
#  6   MAGIC_KEY        1274087 non-null  object
#  7   BOX_COUNT        1274087 non-null  int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 77.8+ MB

# %%
df.head()
# Out:
#    BOX_ID  QUALITY      DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE    MAGIC_KEY  \
# 0       1  Premium  Home Delivery - CoD   0.0   2.7        9.96  2C88D36D1FC
# 1       2  Premium  Home Delivery - CoD   0.0   2.3       11.96  2BC4127366C
# 2       2  Premium  Home Delivery - CoD   0.0   2.3       11.96  2BC4394CE95
# 3       2  Premium  Home Delivery - CoD   0.0   2.3       11.96  2BC4D37C804
# 4       2  Premium  Home Delivery - CoD   0.0   2.3       11.96  2BC4EA26F92
#
#    BOX_COUNT
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder() #creating an instance of that encoder

# %%
rank = ['Standard', 'Premium'] #defining the rank or order
oe = OrdinalEncoder(categories = [rank]) #creating another instance using custom rank
df['QUALITY'] = oe.fit_transform(df[['QUALITY']]) #encoding the column

# %%
rank = ['Home Delivery - Digital Payment', 'Home Delivery - CoD', 'Delivery from Collection Point'] #defining the rank or order
oe = OrdinalEncoder(categories = [rank]) #creating another instance using custom rank
df['DELIVERY_OPTION'] = oe.fit_transform(df[['DELIVERY_OPTION']]) #encoding the column

# %%
from sklearn.preprocessing import LabelEncoder #importing the labenconder
le = LabelEncoder() #creating an instance of LabelEncoder

df['MAGIC_KEY_ENCODED'] = le.fit_transform(df['MAGIC_KEY'])
df_encoded = df.drop(columns = ['MAGIC_KEY'])

# %%
df_encoded.head()
# Out:
#    BOX_ID  QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  BOX_COUNT  \
# 0       1      1.0              1.0   0.0   2.7        9.96          1
# 1       2      1.0              1.0   0.0   2.3       11.96          1
# 2       2      1.0              1.0   0.0   2.3       11.96          1
# 3       2      1.0              1.0   0.0   2.3       11.96          1
# 4       2      1.0              1.0   0.0   2.3       11.96          1
#
#    MAGIC_KEY_ENCODED
# 0             907647
# 1             344150
# 2             344709
# 3             346734
# 4             347034

# %%
sns.set(font_scale = 2)
plt.subplots(figsize = (10, 5))
heat_plot = sns.heatmap(df_encoded.corr(method = 'pearson'), annot = True, cmap = 'RdYlGn', annot_kws={'size': 10})

plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)

plt.show()

# %%
correlation = df_encoded.corr(method = 'pearson') #finding all correlation between each features
print(correlation['BOX_ID'].sort_values(ascending = False).to_string()) #printing correlation with class in descending order
# Out:
# BOX_ID               1.000000
# DELIVERY_OPTION      0.415151
# UNIT_PRICE           0.237738
# MILK                 0.124559
# MEAT                 0.060570
# BOX_COUNT           -0.006333
# MAGIC_KEY_ENCODED   -0.606745
# QUALITY             -0.817314

# %%
from sklearn.utils import shuffle #importing the suffle module
shuffled_df = shuffle(df_encoded)
shuffled_df #checking
# Out:
#          BOX_ID  QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  BOX_COUNT  \
# 1270925     272      0.0              2.0  16.0   2.2       19.98          1
# 249728       89      1.0              2.0  10.0   0.0       12.18          1
# 440176      118      1.0              2.0   8.0   1.3       15.98          1
# 803693      162      1.0              2.0  10.0   2.2       23.98          1
# 897591      163      1.0              2.0  11.0   2.2       23.98          1
# ...         ...      ...              ...   ...   ...         ...        ...
# 338469      103      1.0              2.0   0.0   4.0       15.96          1
# 385539      106      1.0              2.0   0.0   3.3       15.96          1
# 682785      143      1.0              2.0  16.0   1.8       19.98          1
# 108298       31      1.0              1.0   8.0   1.3       15.98          1
# 85658        24      1.0              1.0   0.0   2.5       13.96          1
#
#          MAGIC_KEY_ENCODED
# 1270925             285208
# 249728              496575
# 440176              527695
# 803693             1165240
# 897591             1054116
# ...                    ...
# 338469              459625
# 385539              802966
# 682785              959364
# 108298              380641
# 85658               758976
#
# [1274087 rows x 8 columns]

# %%
#rearranging the index value
rearranged_df = shuffled_df.reset_index(drop = True)
rearranged_df
# Out:
#          BOX_ID  QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  BOX_COUNT  \
# 0           272      0.0              2.0  16.0   2.2       19.98          1
# 1            89      1.0              2.0  10.0   0.0       12.18          1
# 2           118      1.0              2.0   8.0   1.3       15.98          1
# 3           162      1.0              2.0  10.0   2.2       23.98          1
# 4           163      1.0              2.0  11.0   2.2       23.98          1
# ...         ...      ...              ...   ...   ...         ...        ...
# 1274082     103      1.0              2.0   0.0   4.0       15.96          1
# 1274083     106      1.0              2.0   0.0   3.3       15.96          1
# 1274084     143      1.0              2.0  16.0   1.8       19.98          1
# 1274085      31      1.0              1.0   8.0   1.3       15.98          1
# 1274086      24      1.0              1.0   0.0   2.5       13.96          1
#
#          MAGIC_KEY_ENCODED
# 0                   285208
# 1                   496575
# 2                   527695
# 3                  1165240
# 4                  1054116
# ...                    ...
# 1274082             459625
# 1274083             802966
# 1274084             959364
# 1274085             380641
# 1274086             758976
#
# [1274087 rows x 8 columns]

# %%
X = rearranged_df.drop(columns = ['BOX_ID']) #dropping the class collumn to separate the feature
X
# Out:
#          QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  BOX_COUNT  \
# 0            0.0              2.0  16.0   2.2       19.98          1
# 1            1.0              2.0  10.0   0.0       12.18          1
# 2            1.0              2.0   8.0   1.3       15.98          1
# 3            1.0              2.0  10.0   2.2       23.98          1
# 4            1.0              2.0  11.0   2.2       23.98          1
# ...          ...              ...   ...   ...         ...        ...
# 1274082      1.0              2.0   0.0   4.0       15.96          1
# 1274083      1.0              2.0   0.0   3.3       15.96          1
# 1274084      1.0              2.0  16.0   1.8       19.98          1
# 1274085      1.0              1.0   8.0   1.3       15.98          1
# 1274086      1.0              1.0   0.0   2.5       13.96          1
#
#          MAGIC_KEY_ENCODED
# 0                   285208
# 1                   496575
# 2                   527695
# 3                  1165240
# 4                  1054116
# ...                    ...
# 1274082             459625
# 1274083             802966
# 1274084             959364
# 1274085             380641
# 1274086             758976
#
# [1274087 rows x 7 columns]

# %%
y =  rearranged_df['BOX_ID'] #separating target to y
y
# Out:
# 0          272
# 1           89
# 2          118
# 3          162
# 4          163
#           ...
# 1274082    103
# 1274083    106
# 1274084    143
# 1274085     31
# 1274086     24
# Name: BOX_ID, Length: 1274087, dtype: int64

# %%
from sklearn.model_selection import train_test_split #importing module
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20) #80-20% split

# %%
print(len(X_train)) #checking
print(len(X_test))
# Out:
# 1019269
# 254818

# %%
print(len(y_train)) #checking
print(len(y_test))
# Out:
# 1019269
# 254818

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_clf = DecisionTreeClassifier(max_depth = 5, random_state = 42)
tree_clf.fit(X, y)
tree_clf.feature_importances_
# Out:
# array([0.14384212, 0.01991818, 0.34601494, 0.24079475, 0.24943001,
#        0.        , 0.        ])

# %%
#creating instance of decision tree, depth 2
tree_clf = DecisionTreeClassifier(max_depth = 20, random_state = 42)
tree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=20, random_state=42)

# %%
y_pred = tree_clf.predict(X_test)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9999568319349497

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=10, criterion="entropy", random_state = 42)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=42)

# %%
y_pred = classifier.predict(X_test)

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9999097395003492

# %%
df_problem = pd.read_csv('Datasets/problem 2.csv')
df_problem

# %%
df = df.drop(columns = ['BOX_ID'])
df
# Out:
#          QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE    MAGIC_KEY  \
# 0            1.0              1.0   0.0   2.7        9.96  2C88D36D1FC
# 1            1.0              1.0   0.0   2.3       11.96  2BC4127366C
# 2            1.0              1.0   0.0   2.3       11.96  2BC4394CE95
# 3            1.0              1.0   0.0   2.3       11.96  2BC4D37C804
# 4            1.0              1.0   0.0   2.3       11.96  2BC4EA26F92
# ...          ...              ...   ...   ...         ...          ...
# 1274082      0.0              0.0   0.0   3.6       15.96  293C58DD9DC
# 1274083      0.0              0.0   0.0   3.6       15.96  29E6A06C99B
# 1274084      0.0              0.0   0.0   3.6       15.96  2A0CABFA0DF
# 1274085      0.0              0.0  12.0   1.8       19.98  28F675D813E
# 1274086      0.0              0.0  12.0   1.8       19.98  28FF7857D43
#
#          BOX_COUNT  MAGIC_KEY_ENCODED
# 0                1             907647
# 1                1             344150
# 2                1             344709
# 3                1             346734
# 4                1             347034
# ...            ...                ...
# 1274082          1             244323
# 1274083          1             316993
# 1274084          1             331756
# 1274085          1             117129
# 1274086          1             146942
#
# [1274087 rows x 8 columns]

# %%
df_test = pd.merge(df_problem, df, on = 'MAGIC_KEY')
df_test
# Out:
#          MAGIC_KEY  QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  \
# 0      2C0B5F97180      1.0              2.0  12.0   1.8       19.98
# 1      2C2F659EF00      1.0              2.0  16.0   1.8       19.98
# 2      29D629EDF20      0.0              2.0  10.7   0.0       12.78
# 3      2A7073E2FF0      0.0              2.0   8.5   0.0       10.14
# 4      2A9B9BE1210      0.0              2.0  16.0   2.0       19.98
# ...            ...      ...              ...   ...   ...         ...
# 43513  2C49A3D7EAD      1.0              2.0  10.0   1.8       19.98
# 43514  2C49C75F0D8      1.0              0.0   0.0   2.9       15.96
# 43515  2C49CA2A632      1.0              2.0   0.0   3.6       15.96
# 43516  2C49D52753F      1.0              1.0  12.0   1.8       19.98
# 43517  2C49DF0ADB4      1.0              2.0  10.0   1.8       19.98
#
#        BOX_COUNT  MAGIC_KEY_ENCODED
# 0              1             594331
# 1              1             697598
# 2              1             309141
# 3              1             338384
# 4              1             339823
# ...          ...                ...
# 43513          1             764666
# 43514          1             764760
# 43515          1             764777
# 43516          1             764867
# 43517          1             764962
#
# [43518 rows x 8 columns]

# %%
df_test_X = df_test.drop(columns = ['MAGIC_KEY'])
df_test_X
# Out:
#        QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  BOX_COUNT  \
# 0          1.0              2.0  12.0   1.8       19.98          1
# 1          1.0              2.0  16.0   1.8       19.98          1
# 2          0.0              2.0  10.7   0.0       12.78          1
# 3          0.0              2.0   8.5   0.0       10.14          1
# 4          0.0              2.0  16.0   2.0       19.98          1
# ...        ...              ...   ...   ...         ...        ...
# 43513      1.0              2.0  10.0   1.8       19.98          1
# 43514      1.0              0.0   0.0   2.9       15.96          1
# 43515      1.0              2.0   0.0   3.6       15.96          1
# 43516      1.0              1.0  12.0   1.8       19.98          1
# 43517      1.0              2.0  10.0   1.8       19.98          1
#
#        MAGIC_KEY_ENCODED
# 0                 594331
# 1                 697598
# 2                 309141
# 3                 338384
# 4                 339823
# ...                  ...
# 43513             764666
# 43514             764760
# 43515             764777
# 43516             764867
# 43517             764962
#
# [43518 rows x 7 columns]

# %%
y_pred = tree_clf.predict(df_test_X)
y_pred
# Out:
# array([137, 143, 238, ..., 108,  40, 134], dtype=int64)

# %%
# Add the predicted values as a new column to X_test
df_test['BOX_ID'] = y_pred

# Now X_test contains the predicted values in the 'y_pred' column
df_test
# Out:
#          MAGIC_KEY  QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  \
# 0      2C0B5F97180      1.0              2.0  12.0   1.8       19.98
# 1      2C2F659EF00      1.0              2.0  16.0   1.8       19.98
# 2      29D629EDF20      0.0              2.0  10.7   0.0       12.78
# 3      2A7073E2FF0      0.0              2.0   8.5   0.0       10.14
# 4      2A9B9BE1210      0.0              2.0  16.0   2.0       19.98
# ...            ...      ...              ...   ...   ...         ...
# 43513  2C49A3D7EAD      1.0              2.0  10.0   1.8       19.98
# 43514  2C49C75F0D8      1.0              0.0   0.0   2.9       15.96
# 43515  2C49CA2A632      1.0              2.0   0.0   3.6       15.96
# 43516  2C49D52753F      1.0              1.0  12.0   1.8       19.98
# 43517  2C49DF0ADB4      1.0              2.0  10.0   1.8       19.98
#
#        BOX_COUNT  MAGIC_KEY_ENCODED  BOX_ID
# 0              1             594331     137
# 1              1             697598     143
# 2              1             309141     238
# 3              1             338384     231
# 4              1             339823     270
# ...          ...                ...     ...
# 43513          1             764666     134
# 43514          1             764760     182
# 43515          1             764777     108
# 43516          1             764867      40
# 43517          1             764962     134
#
# [43518 rows x 9 columns]

# %%
solutions = df_test[['MAGIC_KEY', 'BOX_ID']].copy()
solutions
# Out:
#          MAGIC_KEY  BOX_ID
# 0      2C0B5F97180     137
# 1      2C2F659EF00     143
# 2      29D629EDF20     238
# 3      2A7073E2FF0     231
# 4      2A9B9BE1210     270
# ...            ...     ...
# 43513  2C49A3D7EAD     134
# 43514  2C49C75F0D8     182
# 43515  2C49CA2A632     108
# 43516  2C49D52753F      40
# 43517  2C49DF0ADB4     134
#
# [43518 rows x 2 columns]

# %%
solutions.to_csv("Submission.csv", index=False)  # Save test data
