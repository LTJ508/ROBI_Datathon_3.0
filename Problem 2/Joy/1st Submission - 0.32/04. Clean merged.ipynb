# %%
import pandas as pd

# %%
df = pd.read_csv('Datasets/merged_df.csv')
df
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT  QUALITY  \
# 0          2019-02-01  2CED678A247    12.0        1.0  Premium
# 1          2019-02-01  2BF58D91BA1    12.0        1.0  Premium
# 2          2019-02-01  2C15B86534E    99.0        1.0  Premium
# 3          2019-02-01  2C32D9A859A     6.0        1.0  Premium
# 4          2019-02-01  2C7A55404D1     4.0        1.0  Premium
# ...               ...          ...     ...        ...      ...
# 2455718    2018-10-28  2BD992B5538    12.0        1.0  Premium
# 2455719    2018-10-28  2C97CD72233    17.0        1.0  Premium
# 2455720    2018-10-28  2C91C61D372    40.0        1.0  Premium
# 2455721    2018-10-28  2CD70CFC4E3    51.0        1.0  Premium
# 2455722    2018-10-28  2C4792A5B84     4.0        1.0  Premium
#
#                         DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE PURCHASE
# 0                   Home Delivery - CoD   8.0   1.5       12.98        Y
# ...

# %%
df = df.drop(columns = ['PURCHASE'])
df = df.drop(columns = ['PURCHASE_DATE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2455723 entries, 0 to 2455722
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   MAGIC_KEY        object
#  1   BOX_ID           float64
#  2   BOX_COUNT        float64
#  3   QUALITY          object
#  4   DELIVERY_OPTION  object
#  5   MILK             float64
#  6   MEAT             float64
#  7   UNIT_PRICE       float64
# dtypes: float64(5), object(3)
# memory usage: 149.9+ MB

# %%
# Group by 'MAGIC_KEY' and calculate mode of 'BOX_ID' and mean of 'BOX_COUNT'
new_df = df.groupby('MAGIC_KEY').agg({'BOX_ID': lambda x: x.mode().iloc[0], 'BOX_COUNT': 'mean'}).reset_index()

# Convert 'BOX_COUNT' mean to integer
new_df['BOX_COUNT'] = new_df['BOX_COUNT'].astype(int)

# Display the new DataFrame
print(new_df)
# Out:
#            MAGIC_KEY  BOX_ID  BOX_COUNT
# 0        249670911D8   231.0          1
# 1        249751FC4DD   260.0          1
# 2        24978027606    27.0          1
# 3        24979164422   246.0          1
# 4        2497B8B4FDA   255.0          1
# ...              ...     ...        ...
# 1274082  2E6F72C6F1C   126.0          1
# 1274083  2E6F8194908    76.0          1
# 1274084  2E6F9C7B9B4   144.0          1
# 1274085  2E6FB0EBB32   258.0          1
# 1274086  2E6FBE224FA    78.0          1
#
# [1274087 rows x 3 columns]

# %%
new_df
# Out:
#            MAGIC_KEY  BOX_ID  BOX_COUNT
# 0        249670911D8   231.0          1
# 1        249751FC4DD   260.0          1
# 2        24978027606    27.0          1
# 3        24979164422   246.0          1
# 4        2497B8B4FDA   255.0          1
# ...              ...     ...        ...
# 1274082  2E6F72C6F1C   126.0          1
# 1274083  2E6F8194908    76.0          1
# 1274084  2E6F9C7B9B4   144.0          1
# 1274085  2E6FB0EBB32   258.0          1
# 1274086  2E6FBE224FA    78.0          1
#
# [1274087 rows x 3 columns]

# %%
new_df.describe()
# Out:
#              BOX_ID     BOX_COUNT
# count  1.274087e+06  1.274087e+06
# mean   1.452858e+02  1.000580e+00
# std    7.302610e+01  2.936397e-02
# min    1.000000e+00  1.000000e+00
# 25%    9.400000e+01  1.000000e+00
# 50%    1.430000e+02  1.000000e+00
# 75%    2.050000e+02  1.000000e+00
# max    2.900000e+02  1.200000e+01

# %%
boxes = pd.read_csv('Datasets/boxes.csv')
boxes
# Out:
#      BOX_ID   QUALITY                  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE
# 0         1   Premium              Home Delivery - CoD   0.0   2.7        9.96
# 1         2   Premium              Home Delivery - CoD   0.0   2.3       11.96
# 2         3   Premium              Home Delivery - CoD   0.0   2.4       11.96
# 3         4   Premium              Home Delivery - CoD   0.0   2.5       11.96
# 4         5   Premium              Home Delivery - CoD   0.0   2.6       11.96
# ..      ...       ...                              ...   ...   ...         ...
# 285     286  Standard  Home Delivery - Digital Payment   0.0   4.0       15.96
# 286     287  Standard  Home Delivery - Digital Payment   0.0   2.9       15.96
# 287     288  Standard  Home Delivery - Digital Payment   0.0   3.6       15.96
# 288     289  Standard  Home Delivery - Digital Payment   0.0   4.7       15.96
# 289     290  Standard  Home Delivery - Digital Payment  12.0   1.8       19.98
#
# [290 rows x 6 columns]

# %%
merged_df = pd.merge(boxes, new_df, on = 'BOX_ID', how = 'inner')
merged_df
# Out:
#          BOX_ID   QUALITY                  DELIVERY_OPTION  MILK  MEAT  \
# 0             1   Premium              Home Delivery - CoD   0.0   2.7
# 1             2   Premium              Home Delivery - CoD   0.0   2.3
# 2             2   Premium              Home Delivery - CoD   0.0   2.3
# 3             2   Premium              Home Delivery - CoD   0.0   2.3
# 4             2   Premium              Home Delivery - CoD   0.0   2.3
# ...         ...       ...                              ...   ...   ...
# 1274082     288  Standard  Home Delivery - Digital Payment   0.0   3.6
# 1274083     288  Standard  Home Delivery - Digital Payment   0.0   3.6
# 1274084     288  Standard  Home Delivery - Digital Payment   0.0   3.6
# 1274085     290  Standard  Home Delivery - Digital Payment  12.0   1.8
# 1274086     290  Standard  Home Delivery - Digital Payment  12.0   1.8
#
#          UNIT_PRICE    MAGIC_KEY  BOX_COUNT
# 0              9.96  2C88D36D1FC          1
# ...

# %%
merged_df.to_csv("main_data.csv", index=False)  # Save test data
