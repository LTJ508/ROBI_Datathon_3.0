# %%
import pandas as pd

# %%
df_problem = pd.read_csv('Datasets/problem 2.csv')
df_merged = pd.read_csv('../Common Datasets/merged_df.csv')

# %%
filtered_df = df_merged[df_merged['MAGIC_KEY'].isin(df_problem['MAGIC_KEY'])]

# %%
filtered_df
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT   QUALITY  \
# 2          2019-02-01  2C15B86534E    99.0        1.0   Premium
# 5          2019-02-01  29D969045C2   238.0        1.0  Standard
# 8          2019-02-01  2A00DE30F46   204.0        1.0  Standard
# 43         2019-02-01  2C2CC83BB99   174.0        1.0   Premium
# 61         2019-02-01  2BE02E54CA0   108.0        1.0   Premium
# ...               ...          ...     ...        ...       ...
# 2455569    2018-10-28  2BEC767D4A1   163.0        1.0   Premium
# 2455627    2018-10-28  2BEA4C45A94   143.0        1.0   Premium
# 2455628    2018-10-28  2BF66227CE9   143.0        1.0   Premium
# 2455660    2018-10-28  2C026D65124   143.0        1.0   Premium
# 2455672    2018-10-28  2C0E3E53ED0   137.0        1.0   Premium
#
#                         DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE PURCHASE
# 2        Delivery from Collection Point   0.0   3.3       13.96        Y
# ...

# %%
filtered_df.PURCHASE.value_counts()
# Out:
# PURCHASE
# Y    108396
# N     60154
# Name: count, dtype: int64

# %%
df_problem
# Out:
#          MAGIC_KEY
# 0      2C0B5F97180
# 1      2C2F659EF00
# 2      29D629EDF20
# 3      2A7073E2FF0
# 4      2A9B9BE1210
# ...            ...
# 43513  2C49A3D7EAD
# 43514  2C49C75F0D8
# 43515  2C49CA2A632
# 43516  2C49D52753F
# 43517  2C49DF0ADB4
#
# [43518 rows x 1 columns]
