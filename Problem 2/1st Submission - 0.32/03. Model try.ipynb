# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Datasets/train.csv')

# %%
df
# Out:
#          BOX_ID   QUALITY                  DELIVERY_OPTION  MILK  MEAT  \
# 0             2   Premium              Home Delivery - CoD   0.0   2.3
# 1             2   Premium              Home Delivery - CoD   0.0   2.3
# 2             2   Premium              Home Delivery - CoD   0.0   2.3
# 3             2   Premium              Home Delivery - CoD   0.0   2.3
# 4             2   Premium              Home Delivery - CoD   0.0   2.3
# ...         ...       ...                              ...   ...   ...
# 1048931     288  Standard  Home Delivery - Digital Payment   0.0   3.6
# 1048932     288  Standard  Home Delivery - Digital Payment   0.0   3.6
# 1048933     288  Standard  Home Delivery - Digital Payment   0.0   3.6
# 1048934     288  Standard  Home Delivery - Digital Payment   0.0   3.6
# 1048935     290  Standard  Home Delivery - Digital Payment  12.0   1.8
#
#          UNIT_PRICE    MAGIC_KEY  BOX_COUNT
# 0             11.96  2BC4127366C          1
# 1             11.96  2BC4394CE95          1
# 2             11.96  2BC4D37C804          1
# 3             11.96  2BC4EA26F92          1
# 4             11.96  2BC4F73408A          1
# ...             ...          ...        ...
# 1048931       15.96  28E5FB5E7BF          1
# 1048932       15.96  293C58DD9DC          1
# 1048933       15.96  29E6A06C99B          1
# 1048934       15.96  2A0CABFA0DF          1
# 1048935       19.98  28F675D813E          1
#
# [1048936 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048936 entries, 0 to 1048935
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   BOX_ID           1048936 non-null  int64
#  1   QUALITY          1048936 non-null  object
#  2   DELIVERY_OPTION  1048936 non-null  object
#  3   MILK             1048936 non-null  float64
#  4   MEAT             1048936 non-null  float64
#  5   UNIT_PRICE       1048936 non-null  float64
#  6   MAGIC_KEY        1048936 non-null  object
#  7   BOX_COUNT        1048936 non-null  int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 64.0+ MB

# %%
df.head()
# Out:
#    BOX_ID  QUALITY      DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE    MAGIC_KEY  \
# 0       2  Premium  Home Delivery - CoD   0.0   2.3       11.96  2BC4127366C
# 1       2  Premium  Home Delivery - CoD   0.0   2.3       11.96  2BC4394CE95
# 2       2  Premium  Home Delivery - CoD   0.0   2.3       11.96  2BC4D37C804
# 3       2  Premium  Home Delivery - CoD   0.0   2.3       11.96  2BC4EA26F92
# 4       2  Premium  Home Delivery - CoD   0.0   2.3       11.96  2BC4F73408A
#
#    BOX_COUNT
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder() #creating an instance of that encoder

# %%
rank = ['Standard', 'Premium'] #defining the rank or order
oe = OrdinalEncoder(categories = [rank]) #creating another instance using custom rank
df['QUALITY'] = oe.fit_transform(df[['QUALITY']]) #encoding the column

# %%
rank = ['Home Delivery - Digital Payment', 'Home Delivery - CoD', 'Delivery from Collection Point'] #defining the rank or order
oe = OrdinalEncoder(categories = [rank]) #creating another instance using custom rank
df['DELIVERY_OPTION'] = oe.fit_transform(df[['DELIVERY_OPTION']]) #encoding the column

# %%
from sklearn.preprocessing import LabelEncoder #importing the labenconder
le = LabelEncoder() #creating an instance of LabelEncoder

df['MAGIC_KEY_ENCODED'] = le.fit_transform(df['MAGIC_KEY'])
df_encoded = df.drop(columns = ['MAGIC_KEY'])

# %%
df_encoded.head()
# Out:
#    BOX_ID  QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  BOX_COUNT  \
# 0       2      1.0              1.0   0.0   2.3       11.96          1
# 1       2      1.0              1.0   0.0   2.3       11.96          1
# 2       2      1.0              1.0   0.0   2.3       11.96          1
# 3       2      1.0              1.0   0.0   2.3       11.96          1
# 4       2      1.0              1.0   0.0   2.3       11.96          1
#
#    MAGIC_KEY_ENCODED
# 0             298333
# 1             298785
# 2             300413
# 3             300652
# 4             300851

# %%
sns.set(font_scale = 2)
plt.subplots(figsize = (10, 5))
heat_plot = sns.heatmap(df_encoded.corr(method = 'pearson'), annot = True, cmap = 'RdYlGn', annot_kws={'size': 10})

plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)

plt.show()

# %%
correlation = df_encoded.corr(method = 'pearson') #finding all correlation between each features
print(correlation['BOX_ID'].sort_values(ascending = False).to_string()) #printing correlation with class in descending order
# Out:
# BOX_ID               1.000000
# DELIVERY_OPTION      0.408524
# UNIT_PRICE           0.188652
# MILK                 0.072247
# MEAT                 0.054362
# BOX_COUNT           -0.003785
# MAGIC_KEY_ENCODED   -0.614492
# QUALITY             -0.816143

# %%
from sklearn.utils import shuffle #importing the suffle module
shuffled_df = shuffle(df_encoded)
shuffled_df #checking
# Out:
#         BOX_ID  QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  BOX_COUNT  \
# 527502     143      1.0              2.0  16.0   1.8       19.98          1
# 41011       12      1.0              1.0   8.0   1.5       12.98          1
# 967229     258      0.0              2.0   8.0   2.2       17.98          1
# 207709      89      1.0              2.0  10.0   0.0       12.18          1
# 213145      94      1.0              2.0   0.0   2.4       13.96          1
# ...        ...      ...              ...   ...   ...         ...        ...
# 806515     228      0.0              2.0   8.3   0.0        9.96          1
# 10534        4      1.0              1.0   0.0   2.5       11.96          1
# 276622     106      1.0              2.0   0.0   3.3       15.96          1
# 410615     132      1.0              2.0   9.0   1.8       19.98          1
# 764343     203      0.0              1.0  10.2   0.0       12.18          1
#
#         MAGIC_KEY_ENCODED
# 527502             730348
# 41011              535793
# 967229              67465
# 207709            1002413
# 213145             567935
# ...                   ...
# 806515              15292
# 10534              325230
# 276622             617255
# 410615             637022
# 764343              25279
#
# [1048936 rows x 8 columns]

# %%
#rearranging the index value
rearranged_df = shuffled_df.reset_index(drop = True)
rearranged_df
# Out:
#          BOX_ID  QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  BOX_COUNT  \
# 0           143      1.0              2.0  16.0   1.8       19.98          1
# 1            12      1.0              1.0   8.0   1.5       12.98          1
# 2           258      0.0              2.0   8.0   2.2       17.98          1
# 3            89      1.0              2.0  10.0   0.0       12.18          1
# 4            94      1.0              2.0   0.0   2.4       13.96          1
# ...         ...      ...              ...   ...   ...         ...        ...
# 1048931     228      0.0              2.0   8.3   0.0        9.96          1
# 1048932       4      1.0              1.0   0.0   2.5       11.96          1
# 1048933     106      1.0              2.0   0.0   3.3       15.96          1
# 1048934     132      1.0              2.0   9.0   1.8       19.98          1
# 1048935     203      0.0              1.0  10.2   0.0       12.18          1
#
#          MAGIC_KEY_ENCODED
# 0                   730348
# 1                   535793
# 2                    67465
# 3                  1002413
# 4                   567935
# ...                    ...
# 1048931              15292
# 1048932             325230
# 1048933             617255
# 1048934             637022
# 1048935              25279
#
# [1048936 rows x 8 columns]

# %%
X = rearranged_df.drop(columns = ['BOX_ID']) #dropping the class collumn to separate the feature
X
# Out:
#          QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  BOX_COUNT  \
# 0            1.0              2.0  16.0   1.8       19.98          1
# 1            1.0              1.0   8.0   1.5       12.98          1
# 2            0.0              2.0   8.0   2.2       17.98          1
# 3            1.0              2.0  10.0   0.0       12.18          1
# 4            1.0              2.0   0.0   2.4       13.96          1
# ...          ...              ...   ...   ...         ...        ...
# 1048931      0.0              2.0   8.3   0.0        9.96          1
# 1048932      1.0              1.0   0.0   2.5       11.96          1
# 1048933      1.0              2.0   0.0   3.3       15.96          1
# 1048934      1.0              2.0   9.0   1.8       19.98          1
# 1048935      0.0              1.0  10.2   0.0       12.18          1
#
#          MAGIC_KEY_ENCODED
# 0                   730348
# 1                   535793
# 2                    67465
# 3                  1002413
# 4                   567935
# ...                    ...
# 1048931              15292
# 1048932             325230
# 1048933             617255
# 1048934             637022
# 1048935              25279
#
# [1048936 rows x 7 columns]

# %%
y =  rearranged_df['BOX_ID'] #separating target to y
y
# Out:
# 0          143
# 1           12
# 2          258
# 3           89
# 4           94
#           ...
# 1048931    228
# 1048932      4
# 1048933    106
# 1048934    132
# 1048935    203
# Name: BOX_ID, Length: 1048936, dtype: int64

# %%
from sklearn.model_selection import train_test_split #importing module
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20) #80-20% split

# %%
print(len(X_train)) #checking
print(len(X_test))
# Out:
# 839148
# 209788

# %%
print(len(y_train)) #checking
print(len(y_test))
# Out:
# 839148
# 209788

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_clf = DecisionTreeClassifier(max_depth = 5, random_state = 42)
tree_clf.fit(X, y)
tree_clf.feature_importances_
# Out:
# array([0.09874885, 0.01144578, 0.34975515, 0.25625253, 0.28379769,
#        0.        , 0.        ])

# %%
#creating instance of decision tree, depth 2
tree_clf = DecisionTreeClassifier(max_depth = 15, random_state = 42)
tree_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=15, random_state=42)

# %%
y_pred = tree_clf.predict(X_test)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9954525521002154

# %%
from sklearn.metrics import accuracy_score

# %%
maxdepth = range(1, 31)
scores = []
for d in maxdepth:
    dt = DecisionTreeClassifier(max_depth = d, random_state = 42)
    dt.fit(X_train, y_train)
    y_pred = dt.predict(X_test)
    scores.append(accuracy_score(y_test, y_pred))

# %%
import matplotlib.pyplot as plt #importing marplotlib
#for showing inline
# %matplotlib inline 


plt.plot(maxdepth, scores) #defining axis

plt.xlabel("Value of depth for DTC") #labeling the x-axis
plt.ylabel("Testing Accuracy") #labeling the y-axis
# Out:
# Text(0, 0.5, 'Testing Accuracy')

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=50, criterion="entropy", random_state = 42, n_jobs = -1, max_leaf_nodes = 2**20, max_features = 3)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_features=3,
#                        max_leaf_nodes=1048576, n_estimators=50, n_jobs=-1,
#                        random_state=42)

# %%
y_pred = classifier.predict(X_test)

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9999523328312392

# %%
df_feb = pd.read_csv('Datasets/test.csv')

# %%
df_feb
# Out:
#           MAGIC_KEY  BOX_ID
# 0       2C15B86534E    99.0
# 1       29D969045C2   238.0
# 2       2A00DE30F46   204.0
# 3       291C04B5CBF   231.0
# 4       2955110718F   238.0
# ...             ...     ...
# 180767  2CBCE0DA1CF     9.0
# 180768  2C36487A3C5   126.0
# 180769  2BF041E89A9   138.0
# 180770  2C26890A7CD    51.0
# 180771  28FE30D9AF3   246.0
#
# [180772 rows x 2 columns]

# %%
df = df.drop(columns = ['BOX_ID'])
df
# Out:
#          QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE    MAGIC_KEY  \
# 0            1.0              1.0   0.0   2.3       11.96  2BC4127366C
# 1            1.0              1.0   0.0   2.3       11.96  2BC4394CE95
# 2            1.0              1.0   0.0   2.3       11.96  2BC4D37C804
# 3            1.0              1.0   0.0   2.3       11.96  2BC4EA26F92
# 4            1.0              1.0   0.0   2.3       11.96  2BC4F73408A
# ...          ...              ...   ...   ...         ...          ...
# 1048931      0.0              0.0   0.0   3.6       15.96  28E5FB5E7BF
# 1048932      0.0              0.0   0.0   3.6       15.96  293C58DD9DC
# 1048933      0.0              0.0   0.0   3.6       15.96  29E6A06C99B
# 1048934      0.0              0.0   0.0   3.6       15.96  2A0CABFA0DF
# 1048935      0.0              0.0  12.0   1.8       19.98  28F675D813E
#
#          BOX_COUNT  MAGIC_KEY_ENCODED
# 0                1             298333
# 1                1             298785
# 2                1             300413
# 3                1             300652
# 4                1             300851
# ...            ...                ...
# 1048931          1              56388
# 1048932          1             209777
# 1048933          1             274281
# 1048934          1             287489
# 1048935          1             100443
#
# [1048936 rows x 8 columns]

# %%
df_test = pd.merge(df_feb, df, on = 'MAGIC_KEY')
df_test
# Out:
#           MAGIC_KEY  BOX_ID  QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  \
# 0       2C15B86534E    99.0      1.0              2.0   0.0   2.7       11.96
# 1       29D969045C2   238.0      0.0              2.0  10.7   0.0       12.78
# 2       2A00DE30F46   204.0      0.0              1.0  10.2   0.0       12.18
# 3       291C04B5CBF   231.0      0.0              2.0  10.0   0.0       12.18
# 4       2955110718F   238.0      0.0              2.0  10.7   0.0       12.78
# ...             ...     ...      ...              ...   ...   ...         ...
# 180767  2CBCE0DA1CF     9.0      1.0              1.0  10.0   0.0       12.18
# 180768  2C36487A3C5   126.0      1.0              2.0   8.0   1.5       15.98
# 180769  2BF041E89A9   138.0      1.0              2.0  10.0   1.8       19.98
# 180770  2C26890A7CD    51.0      1.0              2.0  18.0   2.9       23.98
# 180771  28FE30D9AF3   246.0      0.0              2.0   0.0   2.5       13.96
#
#         BOX_COUNT  MAGIC_KEY_ENCODED
# 0               1             526306
# 1               1             268360
# 2               1             282936
# 3               1             183685
# 4               1             222638
# ...           ...                ...
# 180767          1             883431
# 180768          1             600091
# 180769          1             434093
# 180770          1             565276
# 180771          1             123923
#
# [180772 rows x 9 columns]

# %%
df_test = df_test.drop(columns = ['MAGIC_KEY'])
df_test
# Out:
#         BOX_ID  QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  BOX_COUNT  \
# 0         99.0      1.0              2.0   0.0   2.7       11.96          1
# 1        238.0      0.0              2.0  10.7   0.0       12.78          1
# 2        204.0      0.0              1.0  10.2   0.0       12.18          1
# 3        231.0      0.0              2.0  10.0   0.0       12.18          1
# 4        238.0      0.0              2.0  10.7   0.0       12.78          1
# ...        ...      ...              ...   ...   ...         ...        ...
# 180767     9.0      1.0              1.0  10.0   0.0       12.18          1
# 180768   126.0      1.0              2.0   8.0   1.5       15.98          1
# 180769   138.0      1.0              2.0  10.0   1.8       19.98          1
# 180770    51.0      1.0              2.0  18.0   2.9       23.98          1
# 180771   246.0      0.0              2.0   0.0   2.5       13.96          1
#
#         MAGIC_KEY_ENCODED
# 0                  526306
# 1                  268360
# 2                  282936
# 3                  183685
# 4                  222638
# ...                   ...
# 180767             883431
# 180768             600091
# 180769             434093
# 180770             565276
# 180771             123923
#
# [180772 rows x 8 columns]

# %%
df_test_X = df_test.drop(columns = ['BOX_ID'])
df_test_X
# Out:
#         QUALITY  DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE  BOX_COUNT  \
# 0           1.0              2.0   0.0   2.7       11.96          1
# 1           0.0              2.0  10.7   0.0       12.78          1
# 2           0.0              1.0  10.2   0.0       12.18          1
# 3           0.0              2.0  10.0   0.0       12.18          1
# 4           0.0              2.0  10.7   0.0       12.78          1
# ...         ...              ...   ...   ...         ...        ...
# 180767      1.0              1.0  10.0   0.0       12.18          1
# 180768      1.0              2.0   8.0   1.5       15.98          1
# 180769      1.0              2.0  10.0   1.8       19.98          1
# 180770      1.0              2.0  18.0   2.9       23.98          1
# 180771      0.0              2.0   0.0   2.5       13.96          1
#
#         MAGIC_KEY_ENCODED
# 0                  526306
# 1                  268360
# 2                  282936
# 3                  183685
# 4                  222638
# ...                   ...
# 180767             883431
# 180768             600091
# 180769             434093
# 180770             565276
# 180771             123923
#
# [180772 rows x 7 columns]

# %%
df_test_y = df_test['BOX_ID']
df_test_y
# Out:
# 0          99.0
# 1         238.0
# 2         204.0
# 3         231.0
# 4         238.0
#           ...
# 180767      9.0
# 180768    126.0
# 180769    138.0
# 180770     51.0
# 180771    246.0
# Name: BOX_ID, Length: 180772, dtype: float64

# %%
y_pred = tree_clf.predict(df_test_X)
y_pred
# Out:
# array([ 78, 238, 203, ..., 134, 174, 246], dtype=int64)

# %%
metrics.accuracy_score(df_test_y, y_pred)
# Out:
# 0.3004281636536632

# %%
y_pred = classifier.predict(df_test_X)
y_pred
# Out:
# array([ 78, 238, 203, ..., 134, 174, 246], dtype=int64)

# %%
metrics.accuracy_score(df_test_y, y_pred)
# Out:
# 0.3003562498617042

# %%
def max_depth_error(md):
    model = DecisionTreeClassifier(max_depth=md, random_state=42)
    model.fit(X_train, y_train)
    train_acc = 1 - model.score(X_train, y_train)
    val_acc = 1 - model.score(X_test, y_test)
    return {'Max Depth': md, 'Training Error': train_acc, 'Validation Error': val_acc}

# %%
# %%time
errors_df = pd.DataFrame([max_depth_error(md) for md in range(1, 21)])
# Out:
# CPU times: total: 1min 16s
# Wall time: 1min 38s

# %%
errors_df
# Out:
#     Max Depth  Training Error  Validation Error
# 0           1        0.806723          0.805327
# 1           2        0.702422          0.701017
# 2           3        0.647109          0.644951
# 3           4        0.594595          0.593046
# 4           5        0.535407          0.533100
# 5           6        0.464385          0.462124
# 6           7        0.375182          0.373448
# 7           8        0.297069          0.294278
# 8           9        0.212891          0.211037
# 9          10        0.140882          0.139384
# 10         11        0.090193          0.089467
# 11         12        0.054555          0.054093
# 12         13        0.028180          0.028271
# 13         14        0.014381          0.014367
# 14         15        0.004538          0.004547
# 15         16        0.000691          0.000772
# 16         17        0.000248          0.000286
# 17         18        0.000151          0.000195
# 18         19        0.000063          0.000119
# 19         20        0.000000          0.000029
