# %%
import pandas as pd

# %%
df = pd.read_csv('../../Common Datasets/train_df.csv')
df
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT  QUALITY  \
# 0          2019-01-01  2BE4ABE1D99   162.0        1.0  Premium
# 1          2019-01-01  2BF0F5D1852   162.0        1.0  Premium
# 2          2019-01-01  2CA3A78FEA9   162.0        1.0  Premium
# 3          2019-01-01  2C2A89A5F22   162.0        1.0  Premium
# 4          2019-01-01  2C586661A56   162.0        1.0  Premium
# ...               ...          ...     ...        ...      ...
# 1867901    2018-10-28  2BD992B5538    12.0        1.0  Premium
# 1867902    2018-10-28  2C97CD72233    17.0        1.0  Premium
# 1867903    2018-10-28  2C91C61D372    40.0        1.0  Premium
# 1867904    2018-10-28  2CD70CFC4E3    51.0        1.0  Premium
# 1867905    2018-10-28  2C4792A5B84     4.0        1.0  Premium
#
#                         DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE PURCHASE
# 0        Delivery from Collection Point  10.0   2.2       23.98        Y
# 1        Delivery from Collection Point  10.0   2.2       23.98        Y
# 2        Delivery from Collection Point  10.0   2.2       23.98        Y
# 3        Delivery from Collection Point  10.0   2.2       23.98        Y
# 4        Delivery from Collection Point  10.0   2.2       23.98        Y
# ...                                 ...   ...   ...         ...      ...
# 1867901             Home Delivery - CoD   8.0   1.5       12.98        N
# 1867902             Home Delivery - CoD  10.0   1.8       12.98        N
# 1867903             Home Delivery - CoD  12.0   1.8       19.98        N
# 1867904             Home Delivery - CoD  18.0   2.9       23.98        N
# 1867905             Home Delivery - CoD   0.0   2.5       11.96        N
#
# [1867906 rows x 10 columns]

# %%
df = df.drop(columns = ['PURCHASE'])
df['PURCHASE_DATE'] = pd.to_datetime(df['PURCHASE_DATE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867906 entries, 0 to 1867905
# Data columns (total 9 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   PURCHASE_DATE    datetime64[ns]
#  1   MAGIC_KEY        object
#  2   BOX_ID           float64
#  3   BOX_COUNT        float64
#  4   QUALITY          object
#  5   DELIVERY_OPTION  object
#  6   MILK             float64
#  7   MEAT             float64
#  8   UNIT_PRICE       float64
# dtypes: datetime64[ns](1), float64(5), object(3)
# memory usage: 128.3+ MB

# %%
df = df[df['PURCHASE_DATE'].dt.day <= 15]
df = df[df['BOX_COUNT'] <= 1]
df
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT   QUALITY  \
# 0          2019-01-01  2BE4ABE1D99   162.0        1.0   Premium
# 1          2019-01-01  2BF0F5D1852   162.0        1.0   Premium
# 2          2019-01-01  2CA3A78FEA9   162.0        1.0   Premium
# 3          2019-01-01  2C2A89A5F22   162.0        1.0   Premium
# 4          2019-01-01  2C586661A56   162.0        1.0   Premium
# ...               ...          ...     ...        ...       ...
# 1711558    2018-10-14  2C60F8DFD12   106.0        1.0   Premium
# 1711559    2018-10-14  2C2951E4931   134.0        1.0   Premium
# 1711560    2018-10-14  2A0970C954B   231.0        1.0  Standard
# 1711561    2018-10-14  2CDBF128CAC    89.0        1.0   Premium
# 1711562    2018-10-14  2C8EFB5A32D    27.0        1.0   Premium
#
#                         DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE
# 0        Delivery from Collection Point  10.0   2.2       23.98
# 1        Delivery from Collection Point  10.0   2.2       23.98
# 2        Delivery from Collection Point  10.0   2.2       23.98
# 3        Delivery from Collection Point  10.0   2.2       23.98
# 4        Delivery from Collection Point  10.0   2.2       23.98
# ...                                 ...   ...   ...         ...
# 1711558  Delivery from Collection Point   0.0   3.3       15.96
# 1711559  Delivery from Collection Point  10.0   1.8       19.98
# 1711560  Delivery from Collection Point   8.5   0.0       10.14
# 1711561  Delivery from Collection Point  10.0   0.0       12.18
# 1711562             Home Delivery - CoD   0.0   2.9       15.96
#
# [942130 rows x 9 columns]

# %%
df['MAGIC_KEY'].nunique()
# Out:
# 642998

# %%
duplicates =  df[df['MAGIC_KEY'].duplicated(keep='first')] #it will return the duplicated row from the datasets
duplicates
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT   QUALITY  \
# 17347      2019-01-01  2C16D74DC46    89.0        1.0   Premium
# 20028      2019-01-02  2906538CCF7   204.0        1.0  Standard
# 22220      2019-01-02  2BFEBD3EC2A   106.0        1.0   Premium
# 26594      2019-01-02  2C786763E5C    27.0        1.0   Premium
# 27699      2019-01-02  29031A2D688   238.0        1.0  Standard
# ...               ...          ...     ...        ...       ...
# 1711555    2018-10-14  2BE6A85D5D7   134.0        1.0   Premium
# 1711556    2018-10-14  2964D527CE0   231.0        1.0  Standard
# 1711557    2018-10-14  2BE64B66EB4   134.0        1.0   Premium
# 1711559    2018-10-14  2C2951E4931   134.0        1.0   Premium
# 1711561    2018-10-14  2CDBF128CAC    89.0        1.0   Premium
#
#                         DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE
# 17347    Delivery from Collection Point  10.0   0.0       12.18
# 20028               Home Delivery - CoD  10.7   0.0       12.78
# 22220    Delivery from Collection Point   0.0   3.3       15.96
# 26594               Home Delivery - CoD   0.0   2.9       15.96
# 27699    Delivery from Collection Point  10.7   0.0       12.78
# ...                                 ...   ...   ...         ...
# 1711555  Delivery from Collection Point  10.0   1.8       19.98
# 1711556  Delivery from Collection Point   8.5   0.0       10.14
# 1711557  Delivery from Collection Point  10.0   1.8       19.98
# 1711559  Delivery from Collection Point  10.0   1.8       19.98
# 1711561  Delivery from Collection Point  10.0   0.0       12.18
#
# [299132 rows x 9 columns]

# %%
filtered_df = df[~df['MAGIC_KEY'].isin(duplicates['MAGIC_KEY'])]
filtered_df
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT   QUALITY  \
# 1          2019-01-01  2BF0F5D1852   162.0        1.0   Premium
# 2          2019-01-01  2CA3A78FEA9   162.0        1.0   Premium
# 4          2019-01-01  2C586661A56   162.0        1.0   Premium
# 8          2019-01-01  2C1C97E4EC4   162.0        1.0   Premium
# 10         2019-01-01  2C463B5FB4C   162.0        1.0   Premium
# ...               ...          ...     ...        ...       ...
# 1711552    2018-10-14  2CC607FAE25   106.0        1.0   Premium
# 1711553    2018-10-14  2BE6DC4FF9D   134.0        1.0   Premium
# 1711558    2018-10-14  2C60F8DFD12   106.0        1.0   Premium
# 1711560    2018-10-14  2A0970C954B   231.0        1.0  Standard
# 1711562    2018-10-14  2C8EFB5A32D    27.0        1.0   Premium
#
#                         DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE
# 1        Delivery from Collection Point  10.0   2.2       23.98
# 2        Delivery from Collection Point  10.0   2.2       23.98
# 4        Delivery from Collection Point  10.0   2.2       23.98
# 8        Delivery from Collection Point  10.0   2.2       23.98
# 10       Delivery from Collection Point  10.0   2.2       23.98
# ...                                 ...   ...   ...         ...
# 1711552  Delivery from Collection Point   0.0   3.3       15.96
# 1711553  Delivery from Collection Point  10.0   1.8       19.98
# 1711558  Delivery from Collection Point   0.0   3.3       15.96
# 1711560  Delivery from Collection Point   8.5   0.0       10.14
# 1711562             Home Delivery - CoD   0.0   2.9       15.96
#
# [446107 rows x 9 columns]

# %%
filtered_df['MAGIC_KEY'].nunique()
# Out:
# 446107

# %%
filtered_df = filtered_df.drop(columns = ['PURCHASE_DATE'])

# %%
filtered_df.to_csv("train2.csv", index=False)  # Save test data
