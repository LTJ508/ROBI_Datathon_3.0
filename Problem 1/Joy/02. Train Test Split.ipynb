# %%
import pandas as pd

# %%
df = pd.read_csv('../Common Datasets/merged_df.csv')

# %%
df
# Out:
#         PURCHASE_DATE    MAGIC_KEY  BOX_ID  BOX_COUNT  QUALITY  \
# 0          2019-02-01  2CED678A247    12.0        1.0  Premium
# 1          2019-02-01  2BF58D91BA1    12.0        1.0  Premium
# 2          2019-02-01  2C15B86534E    99.0        1.0  Premium
# 3          2019-02-01  2C32D9A859A     6.0        1.0  Premium
# 4          2019-02-01  2C7A55404D1     4.0        1.0  Premium
# ...               ...          ...     ...        ...      ...
# 2455765    2018-10-28  2BD992B5538    12.0        1.0  Premium
# 2455766    2018-10-28  2C97CD72233    17.0        1.0  Premium
# 2455767    2018-10-28  2C91C61D372    40.0        1.0  Premium
# 2455768    2018-10-28  2CD70CFC4E3    51.0        1.0  Premium
# 2455769    2018-10-28  2C4792A5B84     4.0        1.0  Premium
#
#                         DELIVERY_OPTION  MILK  MEAT  UNIT_PRICE
# 0                   Home Delivery - CoD   8.0   1.5       12.98
# 1                   Home Delivery - CoD   8.0   1.5       12.98
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2455770 entries, 0 to 2455769
# Data columns (total 9 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   PURCHASE_DATE    object
#  1   MAGIC_KEY        object
#  2   BOX_ID           float64
#  3   BOX_COUNT        float64
#  4   QUALITY          object
#  5   DELIVERY_OPTION  object
#  6   MILK             float64
#  7   MEAT             float64
#  8   UNIT_PRICE       float64
# dtypes: float64(5), object(4)
# memory usage: 168.6+ MB

# %%
df['PURCHASE_DATE'] = pd.to_datetime(df['PURCHASE_DATE'])

# %%
train_df = df[df['PURCHASE_DATE'] < '2019-02-01']

# Filter the data for February 2019
test_df = df[(df['PURCHASE_DATE'] >= '2019-02-01') & (df['PURCHASE_DATE'] < '2019-03-01')]

# Save the filtered datasets to separate files or data structures
train_df.to_csv("train_df.csv", index=False)  # Save data before February
test_df.to_csv("test_df.csv", index=False)  # Save data for February
